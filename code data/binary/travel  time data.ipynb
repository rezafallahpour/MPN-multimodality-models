# %%
import pandas as pd

# %%
df = pd.read_csv("F:/more work/the netherlands/tt data/Wave5_DiaryID_car_bike_walk_transit_traveltimes_anonymous.csv",sep=";")

# %%
df
# Out:
#        DiaryID  Time_driv  Time_traffic_driv  Dist_driv Status_driv  \
# 0       530190      543.0              507.0     4287.0          OK
# 1       530192      508.0              480.0     4290.0          OK
# 2       530194      433.0              425.0     3574.0          OK
# 3       530199      187.0              184.0     1114.0          OK
# 4       530203     2359.0             2397.0    55367.0          OK
# ...        ...        ...                ...        ...         ...
# 44292   666714      651.0              648.0     6047.0          OK
# 44293   666716     1248.0             1237.0    26777.0          OK
# 44294   666727     1293.0             1240.0    26248.0          OK
# 44295   666730     3750.0             3641.0    74415.0          OK
# 44296   666732     3678.0             3868.0    73512.0          OK
#
#        Time_bike  Dist_bike Status_bike  Time_walk  Dist_walk Status_walk  \
# 0          821.0     4425.0          OK     2870.0     3901.0          OK
# ...

# %% [markdown]
# df
